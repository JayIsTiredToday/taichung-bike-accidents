# %%
import pandas as pd 
import json 
src = '11411.csv'
df = pd.read_csv(src)
df
# Out:
#          ﻿序號  縣市別代碼        機關代碼            市話            傳真     年   月   日   時  \
# 0          1  66000  387130000C  (04)23274275  (04)23288582  2025  11   1   0
# 1          2  66000  387130000C  (04)23274275  (04)23288582  2025  11   1   0
# 2          3  66000  387130000C  (04)23274275  (04)23288582  2025  11   1   1
# 3          4  66000  387130000C  (04)23274275  (04)23288582  2025  11   1   2
# 4          5  66000  387130000C  (04)23274275  (04)23288582  2025  11   1   4
# ...      ...    ...         ...           ...           ...   ...  ..  ..  ..
# 12408  12409  66000  387130000C  (04)23274275  (04)23288582  2025  11  30  22
# 12409  12410  66000  387130000C  (04)23274275  (04)23288582  2025  11  30  22
# 12410  12411  66000  387130000C  (04)23274275  (04)23288582  2025  11  30  22
# 12411  12412  66000  387130000C  (04)23274275  (04)23288582  2025  11  30  22
# 12412  12413  66000  387130000C  (04)23274275  (04)23288582  2025  11  30  23
#
# ...

# %%
df = df[(df['當事者區分(類別)'] == 'F01') | (df['當事者區分(類別)'] == 'F02')]
df['當事者區分(類別)']
# Out:
# 80       F01
# 208      F01
# 240      F01
# 247      F01
# 248      F01
#         ...
# 12204    F01
# 12236    F01
# 12260    F01
# 12343    F01
# 12382    F01
# Name: 當事者區分(類別), Length: 201, dtype: str

# %%
df.to_csv('incidents.csv')
